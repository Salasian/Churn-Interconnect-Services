# %% [markdown]
# # Context of the Analysis

# %% [markdown]
# The telecom operator Interconnect would like to be able to predict its churn rate. If a customer is found to be planning to leave, he or she will be offered promotional codes and special plan options. Interconnect's marketing team has collected some of its customers personal data, including information about their plans and contracts.
#
# ### Interconnect Services
#
# Interconnect provides primarily two types of services:
#
# 1. Landline telephone communication. The telephone can be connected to several lines simultaneously.
# 2. Internet. The network can be set up over a telephone line (DSL, *digital subscriber line*) or over a fiber optic cable.
#
# Some other services offered by the company include:
#
# - Internet security: antivirus software (*DeviceProtection*) and a malicious Web site blocker (*OnlineSecurity*).
# - A technical support hotline (*TechnicalSupport*).
# - Cloud file storage and data backup (*BackupOnline*).
# - TV streaming (*StreamingTV*) and movie directory (*StreamingMovies*).
#
# Customers can choose between a monthly payment or sign a 1 or 2 year contract. You can use several payment methods and receive an electronic invoice after a transaction.
#
# ### Description of the data
#
# The data consists of files obtained from different sources:
#
# - `contract.csv` - contract information;
# - `personal.csv` - customer's personal data;
# - `internet.csv` - information about Internet services;
# - `phone.csv` - information about telephone services.
#
# In each file, the `customerID` column contains a unique code assigned to each customer. The contract information is valid as of February 1, 2020.

# %% [markdown]
# ## Data Detailed Description
# Below is a summary of what each column means for every CSV file in the datasets folder:
#
# ---
#
# ### contract.csv
#
# | Column Name       | Description                                                        |
# |-------------------|--------------------------------------------------------------------|
# | customerID        | Unique identifier for each customer                                |
# | BeginDate         | Date when the contract started                                     |
# | EndDate           | Date when the contract ended (if applicable)                       |
# | Type              | Type of contract (e.g., month-to-month, one year, two year)        |
# | PaperlessBilling  | Whether the customer receives electronic invoices (Yes/No)         |
# | PaymentMethod     | Method used for payment (e.g., credit card, bank transfer, etc.)   |
# | MonthlyCharges    | Amount charged to the customer monthly                             |
# | TotalCharges      | Total amount charged to the customer                               |
# | Churn             | Whether the customer has left the service (Yes/No)                 |
#
# ---
#
# ### personal.csv
#
# | Column Name   | Description                                         |
# |---------------|-----------------------------------------------------|
# | customerID    | Unique identifier for each customer                 |
# | Gender        | Customer’s gender                                   |
# | SeniorCitizen | Whether the customer is a senior citizen (1 = Yes, 0 = No) |
# | Partner       | Whether the customer has a partner (Yes/No)         |
# | Dependents    | Whether the customer has dependents (Yes/No)        |
#
# ---
#
# ### internet.csv
#
# | Column Name       | Description                                                        |
# |-------------------|--------------------------------------------------------------------|
# | customerID        | Unique identifier for each customer                                |
# | InternetService   | Type of internet service (DSL, Fiber optic, None)                  |
# | OnlineSecurity    | Whether the customer has online security add-on (Yes/No/No internet)|
# | OnlineBackup      | Whether the customer has online backup add-on (Yes/No/No internet) |
# | DeviceProtection  | Whether the customer has device protection add-on (Yes/No/No internet)|
# | TechSupport       | Whether the customer has technical support add-on (Yes/No/No internet)|
# | StreamingTV       | Whether the customer has streaming TV add-on (Yes/No/No internet)  |
# | StreamingMovies   | Whether the customer has streaming movies add-on (Yes/No/No internet)|
#
# ---
#
# ### phone.csv
#
# | Column Name     | Description                                                        |
# |-----------------|--------------------------------------------------------------------|
# | customerID      | Unique identifier for each customer                                |
# | MultipleLines   | Whether the customer has multiple phone lines (Yes/No/No phone service) |
#
# ---
